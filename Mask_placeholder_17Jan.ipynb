# %%
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import MinMaxScaler  
from pytorch_tabnet.pretraining import TabNetPretrainer
from sklearn.metrics import mean_squared_error
import math

# Load dataset with missing values
omicMiss = pd.read_csv('/Users/emondemoniac/Desktop/TabNet_PyTorch/jiaojiao data/48complete_proteomics.csv')

omicMiss_copy = omicMiss.copy()
print("Input Data with missing Values:")
print(omicMiss.head())

# Normalize the dataset and preprocessing
scaler = MinMaxScaler()  
numeric_cols = omicMiss.columns[1:]
omicMiss[numeric_cols] = scaler.fit_transform(omicMiss[numeric_cols])

print('After Normalizing Input Data:')
print(omicMiss.head())

# Handle missing values by placeholder
missing_value_placeholder = 0
omicMiss.fillna(missing_value_placeholder, inplace=True)

print("\nFilled Missing Values with Placeholder:")
print(omicMiss.head())

# Introduce SSL by randomly masking some values during training
def mask_data(data, mask_prob=0.25):
    mask = (np.random.rand(*data.shape) < mask_prob) & (data == missing_value_placeholder)
    masked_data = data.copy()
    masked_data[mask] = missing_value_placeholder
    return masked_data

# Pretrain the TabNet model with SSL
pretrained_model = TabNetPretrainer(
    optimizer_fn=torch.optim.Adam,
    optimizer_params=dict(lr=2e-2),
    mask_type='sparsemax',
    #n_d=16,  # Increase the number of decision steps
    #n_a=16   # Increase the number of features shared
)

max_epochs = 75
for epoch in range(max_epochs):
    # Mask a percentage of the data for SSL
    masked_data = mask_data(omicMiss[numeric_cols].values)
    pretrained_model.fit(masked_data, max_epochs=1)

print("\nPretrained TabNet Model:")

def tabnet_recon(omicMiss, network, missing_value_placeholder=0, numeric_cols=None, scaler=None):
    # Ensure numeric_cols and scaler are provided
    if numeric_cols is None or scaler is None:
        raise ValueError("Please provide numeric_cols and scaler.")
    
    # Copy the input data
    omicRec_tab = omicMiss.copy()
    
    # Identify the rows and columns where the placeholder value exists
    missing_mask = (omicRec_tab[numeric_cols] == missing_value_placeholder)
    
    # Normalize the input data
    omicRec_tab[numeric_cols] = scaler.transform(omicRec_tab[numeric_cols])
    
    # Convert input data to tensors for use in the TabNet network
    inputData = torch.tensor(omicRec_tab[numeric_cols].values, dtype=torch.float32)
    
    # Pass the input data through the TabNet network
    results = network.predict(inputData)
    
    # Ensure results is a NumPy array
    if isinstance(results, tuple):
        results = results[0]  # Use the first element of the tuple
    elif isinstance(results, torch.Tensor):
        results = results.detach().numpy()  # Convert to NumPy array
    
    omicRec_tab[numeric_cols] = results
    
    # Reassign reconstructed values to the missing positions
    omicRec_tab[numeric_cols] = np.where(missing_mask, omicRec_tab[numeric_cols], omicMiss[numeric_cols])
    
    return omicRec_tab

# Extract true missing values before filling
true_missing_values = omicMiss[numeric_cols].values

print ('\n True missing values: ')
print (true_missing_values)

# Reconstruct missing values using the pretrained model
reconstructed_data = tabnet_recon(
    omicMiss,
    network=pretrained_model,
    numeric_cols=numeric_cols,
    scaler=scaler
)

print ('\n Reconstructed data: ')
print (reconstructed_data.iloc[:10])

# Extract imputed values
imputed_values = reconstructed_data[numeric_cols].values

print ('\n Imputed values: ')
print (imputed_values)

# Calculate RMSE
rmse = np.sqrt(np.mean((imputed_values - true_missing_values) ** 2))

# Denormalize the reconstructed data
reconstructed_data[numeric_cols] = scaler.inverse_transform(reconstructed_data[numeric_cols])

# Print original and reconstructed data
print("Original Data:")
print(omicMiss_copy.iloc[:10])
print("\nDenormalize Reconstructed Data:")
print(reconstructed_data.iloc[:10])

print("RMSE:", rmse)
# Out:
# Input Data with missing Values:
#    Unnamed: 0  Balm_3_1_U_IO_DDA_30min_G6_1_5228  \
# 0       ILVBL                                NaN
# 1     NA;NBAS                           8.937573
# 2  GTPBP10;NA                           8.672674
# 3         PGP                                NaN
# 4     NA;AHSG                          11.804774
#
#    Balm_3_2_T_IO_DDA_30min_H6_1_5230  Balm_3_3_U_IO_DDA_30min_A7_1_5232  \
# 0                           8.935561                                NaN
# 1                           9.367173                                NaN
# 2                           8.955487                                NaN
# 3                           8.596817                                NaN
# 4                          11.778822                          11.864427
#
#    Balm_3_4_T_IO_DDA_30min_B7_1_5234  DOHH_2_1_U_IO_DDA_30_C4_1_5188  \
# 0                                NaN                        9.220390
# 1                                NaN                        8.467625
# 2                                NaN                        9.159973
# 3                                NaN                             NaN
# 4                          12.075907                       11.444936
#
#    DOHH_2_2_T_IO_DDA_30_D4_1_5190  DOHH_2_3_U_IO_DDA_30_E4_1_5192  \
# 0                             NaN                             NaN
# 1                        8.535367                        8.729995
# 2                        8.743835                        9.052879
# 3                        8.679754                             NaN
# 4                       11.350030                       11.449346
#
#    DOHH_2_4_T_IO_DDA_30_F4_1_5194  HBL_1_2_T_IO_DDA_30_H1_1_5150  ...  \
# 0                        8.950183                            NaN  ...
# 1                             NaN                       8.608477  ...
# 2                        8.759308                       8.201907  ...
# 3                        8.616568                       8.696092  ...
# 4                       11.749893                      10.275086  ...
#
#    SU_DHL_5_3_U_IO_DDA_30_A3_1_5168  SU_DHL_5_4_T_IO_DDA_30_B3_1_5170  \
# 0                               NaN                          8.759982
# 1                          8.315028                          8.735943
# 2                          8.343125                          8.468654
# 3                          8.671355                          8.798077
# 4                         10.704165                         10.541333
#
#    TMD_8_1_U_IO_DDA_30_C2_1_5156  TMD_8_2_T_IO_DDA_30_D2_1_5158  \
# 0                       9.557964                       9.990720
# 1                       8.788090                       9.369052
# 2                       8.710834                       8.975048
# 3                       9.370757                       8.818201
# 4                      10.565428                      10.897665
#
#    TMD_8_3_U_IO_DDA_30_E2_1_5160  TMD_8_4_T_IO_DDA_30_F2_1_5162  \
# 0                       9.789927                      10.089345
# 1                       8.928256                       9.288782
# 2                       8.846468                       8.716585
# 3                       9.477080                       9.111724
# 4                      10.769873                      10.358631
#
#    U_2932_1_U_IO_DDA_30min_G5_1_5212  U_2932_2_T_IO_DDA_30min_H5_1_5214  \
# 0                           8.539033                           8.578702
# 1                           8.952269                           8.917941
# 2                           9.122460                           8.997914
# 3                           9.778208                           9.661671
# 4                           9.580386                           9.702839
#
#    U_2932_3_U_IO_DDA_30min_A6_1_5216  U_2932_4_T_IO_DDA_30min_B6_1_5218
# 0                           9.021260                           8.038641
# 1                           8.669605                           8.812814
# 2                           8.967428                           9.267760
# 3                           9.502039                           9.491149
# 4                           9.713053                          10.030737
#
# [5 rows x 49 columns]
# After Normalizing Input Data:
#    Unnamed: 0  Balm_3_1_U_IO_DDA_30min_G6_1_5228  \
# 0       ILVBL                                NaN
# 1     NA;NBAS                           0.311909
# 2  GTPBP10;NA                           0.287711
# 3         PGP                                NaN
# 4     NA;AHSG                           0.573819
#
#    Balm_3_2_T_IO_DDA_30min_H6_1_5230  Balm_3_3_U_IO_DDA_30min_A7_1_5232  \
# 0                           0.373884                                NaN
# 1                           0.413203                                NaN
# 2                           0.375699                                NaN
# 3                           0.343025                                NaN
# 4                           0.632899                             0.5716
#
#    Balm_3_4_T_IO_DDA_30min_B7_1_5234  DOHH_2_1_U_IO_DDA_30_C4_1_5188  \
# 0                                NaN                        0.427089
# 1                                NaN                        0.365927
# 2                                NaN                        0.422180
# 3                                NaN                             NaN
# 4                           0.637162                        0.607831
#
#    DOHH_2_2_T_IO_DDA_30_D4_1_5190  DOHH_2_3_U_IO_DDA_30_E4_1_5192  \
# 0                             NaN                             NaN
# 1                        0.281293                        0.263665
# 2                        0.301266                        0.296179
# 3                        0.295127                             NaN
# 4                        0.550956                        0.537504
#
#    DOHH_2_4_T_IO_DDA_30_F4_1_5194  HBL_1_2_T_IO_DDA_30_H1_1_5150  ...  \
# 0                        0.271054                            NaN  ...
# 1                             NaN                       0.293497  ...
# 2                        0.251655                       0.256263  ...
# 3                        0.237147                       0.301521  ...
# 4                        0.555606                       0.446130  ...
#
#    SU_DHL_5_3_U_IO_DDA_30_A3_1_5168  SU_DHL_5_4_T_IO_DDA_30_B3_1_5170  \
# 0                               NaN                          0.278118
# 1                          0.311718                          0.275801
# 2                          0.314089                          0.250036
# 3                          0.341791                          0.281791
# 4                          0.513353                          0.449834
#
#    TMD_8_1_U_IO_DDA_30_C2_1_5156  TMD_8_2_T_IO_DDA_30_D2_1_5158  \
# 0                       0.301844                       0.431017
# 1                       0.213700                       0.365513
# 2                       0.204855                       0.323998
# 3                       0.280410                       0.307471
# 4                       0.417189                       0.526579
#
#    TMD_8_3_U_IO_DDA_30_E2_1_5160  TMD_8_4_T_IO_DDA_30_F2_1_5162  \
# 0                       0.392369                       0.425073
# 1                       0.302744                       0.337698
# 2                       0.294237                       0.275247
# 3                       0.359829                       0.318373
# 4                       0.494296                       0.454464
#
#    U_2932_1_U_IO_DDA_30min_G5_1_5212  U_2932_2_T_IO_DDA_30min_H5_1_5214  \
# 0                           0.315086                           0.298117
# 1                           0.354074                           0.331361
# 2                           0.370132                           0.339198
# 3                           0.432002                           0.404244
# 4                           0.413337                           0.408278
#
#    U_2932_3_U_IO_DDA_30min_A6_1_5216  U_2932_4_T_IO_DDA_30min_B6_1_5218
# 0                           0.307533                           0.304626
# 1                           0.272715                           0.373002
# 2                           0.302203                           0.413184
# 3                           0.355137                           0.432914
# 4                           0.376030                           0.480571
#
# [5 rows x 49 columns]
#
# Filled Missing Values with Placeholder:
#    Unnamed: 0  Balm_3_1_U_IO_DDA_30min_G6_1_5228  \
# 0       ILVBL                           0.000000
# 1     NA;NBAS                           0.311909
# 2  GTPBP10;NA                           0.287711
# 3         PGP                           0.000000
# 4     NA;AHSG                           0.573819
#
#    Balm_3_2_T_IO_DDA_30min_H6_1_5230  Balm_3_3_U_IO_DDA_30min_A7_1_5232  \
# 0                           0.373884                             0.0000
# 1                           0.413203                             0.0000
# 2                           0.375699                             0.0000
# 3                           0.343025                             0.0000
# 4                           0.632899                             0.5716
#
#    Balm_3_4_T_IO_DDA_30min_B7_1_5234  DOHH_2_1_U_IO_DDA_30_C4_1_5188  \
# 0                           0.000000                        0.427089
# 1                           0.000000                        0.365927
# 2                           0.000000                        0.422180
# 3                           0.000000                        0.000000
# 4                           0.637162                        0.607831
#
#    DOHH_2_2_T_IO_DDA_30_D4_1_5190  DOHH_2_3_U_IO_DDA_30_E4_1_5192  \
# 0                        0.000000                        0.000000
# 1                        0.281293                        0.263665
# 2                        0.301266                        0.296179
# 3                        0.295127                        0.000000
# 4                        0.550956                        0.537504
#
#    DOHH_2_4_T_IO_DDA_30_F4_1_5194  HBL_1_2_T_IO_DDA_30_H1_1_5150  ...  \
# 0                        0.271054                       0.000000  ...
# 1                        0.000000                       0.293497  ...
# 2                        0.251655                       0.256263  ...
# 3                        0.237147                       0.301521  ...
# 4                        0.555606                       0.446130  ...
#
#    SU_DHL_5_3_U_IO_DDA_30_A3_1_5168  SU_DHL_5_4_T_IO_DDA_30_B3_1_5170  \
# 0                          0.000000                          0.278118
# 1                          0.311718                          0.275801
# 2                          0.314089                          0.250036
# 3                          0.341791                          0.281791
# 4                          0.513353                          0.449834
#
#    TMD_8_1_U_IO_DDA_30_C2_1_5156  TMD_8_2_T_IO_DDA_30_D2_1_5158  \
# 0                       0.301844                       0.431017
# 1                       0.213700                       0.365513
# 2                       0.204855                       0.323998
# 3                       0.280410                       0.307471
# 4                       0.417189                       0.526579
#
#    TMD_8_3_U_IO_DDA_30_E2_1_5160  TMD_8_4_T_IO_DDA_30_F2_1_5162  \
# 0                       0.392369                       0.425073
# 1                       0.302744                       0.337698
# 2                       0.294237                       0.275247
# 3                       0.359829                       0.318373
# 4                       0.494296                       0.454464
#
#    U_2932_1_U_IO_DDA_30min_G5_1_5212  U_2932_2_T_IO_DDA_30min_H5_1_5214  \
# 0                           0.315086                           0.298117
# 1                           0.354074                           0.331361
# 2                           0.370132                           0.339198
# 3                           0.432002                           0.404244
# 4                           0.413337                           0.408278
#
#    U_2932_3_U_IO_DDA_30min_A6_1_5216  U_2932_4_T_IO_DDA_30min_B6_1_5218
# 0                           0.307533                           0.304626
# 1                           0.272715                           0.373002
# 2                           0.302203                           0.413184
# 3                           0.355137                           0.432914
# 4                           0.376030                           0.480571
#
# [5 rows x 49 columns]
# Device used : cpu
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 64.24446|  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 27.60899|  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 13.6297 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 8.17952 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 5.51769 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 3.84135 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 2.68204 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 1.88712 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 1.50818 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 1.27648 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 1.16075 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 1.07984 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.88446 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.82481 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.82583 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.8516  |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.82609 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.85349 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.71067 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.75642 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.72089 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.66564 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.64683 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.59214 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.64554 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.57842 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.66246 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.59559 |  0:00:03s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.68006 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.63452 |  0:00:03s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.56062 |  0:00:03s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.53514 |  0:00:03s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.49854 |  0:00:03s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.58401 |  0:00:05s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.58045 |  0:00:04s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.56533 |  0:00:03s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.59941 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.49564 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.56403 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.53582 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.54953 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.5858  |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.57496 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.48399 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.47381 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.47736 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.48775 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.5362  |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.56553 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.44832 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.52079 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.49395 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.53766 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.52407 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.57334 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.49465 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.51401 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.46454 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.4475  |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.55908 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.54981 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.47247 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.4842  |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.46701 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.49337 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.51895 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.45963 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.51797 |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.52135 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.4992  |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.527   |  0:00:01s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.52493 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.51901 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.50938 |  0:00:02s
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.49018 |  0:00:01s
#
# Pretrained TabNet Model:
#
#  True missing values:
# [[0.         0.37388422 0.         ... 0.29811684 0.30753333 0.30462615]
#  [0.31190882 0.41320305 0.         ... 0.33136103 0.27271477 0.37300239]
#  [0.28771114 0.37569938 0.         ... 0.33919817 0.3022032  0.41318402]
#  ...
#  [0.27722101 0.37681039 0.27880987 ... 0.37007423 0.34667955 0.42176785]
#  [0.         0.19858064 0.         ... 0.24540757 0.20429109 0.        ]
#  [0.31769263 0.4379244  0.29077293 ... 0.37514943 0.30910341 0.41183955]]
#
#  Reconstructed data:
#    Unnamed: 0  Balm_3_1_U_IO_DDA_30min_G6_1_5228  \
# 0       ILVBL                           0.132535
# 1     NA;NBAS                           0.311909
# 2  GTPBP10;NA                           0.287711
# 3         PGP                           0.131943
# 4     NA;AHSG                           0.573819
# 5      NA;VTN                           0.560378
# 6        AGPS                           0.202025
# 7      DDX39A                           0.640891
# 8      PDLIM1                           0.130498
# 9   SNAP23;NA                           0.421007
#
#    Balm_3_2_T_IO_DDA_30min_H6_1_5230  Balm_3_3_U_IO_DDA_30min_A7_1_5232  \
# 0                           0.373884                          -0.075729
# 1                           0.413203                          -0.077941
# 2                           0.375699                          -0.076494
# 3                           0.343025                          -0.076895
# 4                           0.632899                           0.571600
# 5                           0.628895                           0.535524
# 6                           0.350973                           0.177465
# 7                           0.703162                           0.607063
# 8                           0.194773                          -0.075842
# 9                           0.494831                           0.416141
#
#    Balm_3_4_T_IO_DDA_30min_B7_1_5234  DOHH_2_1_U_IO_DDA_30_C4_1_5188  \
# 0                          -0.008155                        0.427089
# 1                          -0.010513                        0.365927
# 2                          -0.007966                        0.422180
# 3                          -0.008353                        0.276341
# 4                           0.637162                        0.607831
# 5                           0.598051                        0.550746
# 6                           0.278484                        0.259475
# 7                           0.663505                        0.679416
# 8                          -0.005893                        0.500691
# 9                           0.483997                        0.498416
#
#    DOHH_2_2_T_IO_DDA_30_D4_1_5190  DOHH_2_3_U_IO_DDA_30_E4_1_5192  \
# 0                        0.086846                        0.061632
# 1                        0.281293                        0.263665
# 2                        0.301266                        0.296179
# 3                        0.295127                        0.061250
# 4                        0.550956                        0.537504
# 5                        0.500829                        0.446701
# 6                        0.105639                        0.079729
# 7                        0.632918                        0.617332
# 8                        0.463728                        0.398755
# 9                        0.416287                        0.361174
#
#    DOHH_2_4_T_IO_DDA_30_F4_1_5194  HBL_1_2_T_IO_DDA_30_H1_1_5150  ...  \
# 0                        0.271054                       0.227530  ...
# 1                        0.110712                       0.293497  ...
# 2                        0.251655                       0.256263  ...
# 3                        0.237147                       0.301521  ...
# 4                        0.555606                       0.446130  ...
# 5                        0.459061                       0.404287  ...
# 6                        0.110262                       0.424551  ...
# 7                        0.598597                       0.548534  ...
# 8                        0.383318                       0.395512  ...
# 9                        0.383615                       0.358538  ...
#
#    SU_DHL_5_3_U_IO_DDA_30_A3_1_5168  SU_DHL_5_4_T_IO_DDA_30_B3_1_5170  \
# 0                          0.201334                          0.278118
# 1                          0.311718                          0.275801
# 2                          0.314089                          0.250036
# 3                          0.341791                          0.281791
# 4                          0.513353                          0.449834
# 5                          0.556707                          0.527065
# 6                          0.307418                          0.221605
# 7                          0.644579                          0.607008
# 8                          0.392077                          0.329794
# 9                          0.445964                          0.358584
#
#    TMD_8_1_U_IO_DDA_30_C2_1_5156  TMD_8_2_T_IO_DDA_30_D2_1_5158  \
# 0                       0.301844                       0.431017
# 1                       0.213700                       0.365513
# 2                       0.204855                       0.323998
# 3                       0.280410                       0.307471
# 4                       0.417189                       0.526579
# 5                       0.426157                       0.496232
# 6                       0.266226                       0.356714
# 7                       0.564338                       0.662056
# 8                       0.469016                       0.533448
# 9                       0.352341                       0.416426
#
#    TMD_8_3_U_IO_DDA_30_E2_1_5160  TMD_8_4_T_IO_DDA_30_F2_1_5162  \
# 0                       0.392369                       0.425073
# 1                       0.302744                       0.337698
# 2                       0.294237                       0.275247
# 3                       0.359829                       0.318373
# 4                       0.494296                       0.454464
# 5                       0.466032                       0.496592
# 6                       0.333909                       0.336348
# 7                       0.614372                       0.625936
# 8                       0.515043                       0.531380
# 9                       0.415223                       0.421142
#
#    U_2932_1_U_IO_DDA_30min_G5_1_5212  U_2932_2_T_IO_DDA_30min_H5_1_5214  \
# 0                           0.315086                           0.298117
# 1                           0.354074                           0.331361
# 2                           0.370132                           0.339198
# 3                           0.432002                           0.404244
# 4                           0.413337                           0.408278
# 5                           0.443050                           0.431539
# 6                           0.455420                           0.457405
# 7                           0.640294                           0.646364
# 8                           0.597318                           0.567013
# 9                           0.442070                           0.393128
#
#    U_2932_3_U_IO_DDA_30min_A6_1_5216  U_2932_4_T_IO_DDA_30min_B6_1_5218
# 0                           0.307533                           0.304626
# 1                           0.272715                           0.373002
# 2                           0.302203                           0.413184
# 3                           0.355137                           0.432914
# 4                           0.376030                           0.480571
# 5                           0.396516                           0.427779
# 6                           0.424560                           0.490245
# 7                           0.608123                           0.662498
# 8                           0.527271                           0.609472
# 9                           0.355189                           0.456840
#
# [10 rows x 49 columns]
#
#  Imputed values:
# [[ 0.13253528  0.37388422 -0.07572857 ...  0.29811684  0.30753333
#    0.30462615]
#  [ 0.31190882  0.41320305 -0.07794113 ...  0.33136103  0.27271477
#    0.37300239]
#  [ 0.28771114  0.37569938 -0.07649358 ...  0.33919817  0.3022032
#    0.41318402]
#  ...
#  [ 0.27722101  0.37681039  0.27880987 ...  0.37007423  0.34667955
#    0.42176785]
#  [ 0.13403516  0.19858064 -0.07847288 ...  0.24540757  0.20429109
#    0.37188926]
#  [ 0.31769263  0.4379244   0.29077293 ...  0.37514943  0.30910341
#    0.41183955]]
# Original Data:
#    Unnamed: 0  Balm_3_1_U_IO_DDA_30min_G6_1_5228  \
# 0       ILVBL                                NaN
# 1     NA;NBAS                           8.937573
# 2  GTPBP10;NA                           8.672674
# 3         PGP                                NaN
# 4     NA;AHSG                          11.804774
# 5      NA;VTN                          11.657632
# 6        AGPS                           7.734646
# 7      DDX39A                          12.539039
# 8      PDLIM1                                NaN
# 9   SNAP23;NA                          10.131897
#
#    Balm_3_2_T_IO_DDA_30min_H6_1_5230  Balm_3_3_U_IO_DDA_30min_A7_1_5232  \
# 0                           8.935561                                NaN
# 1                           9.367173                                NaN
# 2                           8.955487                                NaN
# 3                           8.596817                                NaN
# 4                          11.778822                          11.864427
# 5                          11.734868                          11.481394
# 6                           8.684063                           7.679667
# 7                          12.550123                          12.240957
# 8                           6.969415                                NaN
# 9                          10.263223                          10.213836
#
#    Balm_3_4_T_IO_DDA_30min_B7_1_5234  DOHH_2_1_U_IO_DDA_30_C4_1_5188  \
# 0                                NaN                        9.220390
# 1                                NaN                        8.467625
# 2                                NaN                        9.159973
# 3                                NaN                             NaN
# 4                          12.075907                       11.444936
# 5                          11.648854                       10.742336
# 6                           8.159461                        7.157424
# 7                          12.363546                       12.325987
# 8                                NaN                       10.126271
# 9                          10.403475                       10.098273
#
#    DOHH_2_2_T_IO_DDA_30_D4_1_5190  DOHH_2_3_U_IO_DDA_30_E4_1_5192  \
# 0                             NaN                             NaN
# 1                        8.535367                        8.729995
# 2                        8.743835                        9.052879
# 3                        8.679754                             NaN
# 4                       11.350030                       11.449346
# 5                       10.826813                       10.547628
# 6                        6.701936                        6.903436
# 7                       12.205522                       12.242067
# 8                       10.439571                       10.071499
# 9                        9.944390                        9.698307
#
#    DOHH_2_4_T_IO_DDA_30_F4_1_5194  HBL_1_2_T_IO_DDA_30_H1_1_5150  ...  \
# 0                        8.950183                            NaN  ...
# 1                             NaN                       8.608477  ...
# 2                        8.759308                       8.201907  ...
# 3                        8.616568                       8.696092  ...
# 4                       11.749893                      10.275086  ...
# 5                       10.799984                       9.818202  ...
# 6                             NaN                      10.039460  ...
# 7                       12.172878                      11.393241  ...
# 8                       10.054748                       9.722385  ...
# 9                       10.057667                       9.318657  ...
#
#    SU_DHL_5_3_U_IO_DDA_30_A3_1_5168  SU_DHL_5_4_T_IO_DDA_30_B3_1_5170  \
# 0                               NaN                          8.759982
# 1                          8.315028                          8.735943
# 2                          8.343125                          8.468654
# 3                          8.671355                          8.798077
# 4                         10.704165                         10.541333
# 5                         11.217870                         11.342517
# 6                          8.264080                          8.173716
# 7                         12.259045                         12.171843
# 8                          9.267193                          9.296059
# 9                          9.905685                          9.594718
#
#    TMD_8_1_U_IO_DDA_30_C2_1_5156  TMD_8_2_T_IO_DDA_30_D2_1_5158  \
# 0                       9.557964                       9.990720
# 1                       8.788090                       9.369052
# 2                       8.710834                       8.975048
# 3                       9.370757                       8.818201
# 4                      10.565428                      10.897665
# 5                      10.643757                      10.609650
# 6                       9.246865                       9.285541
# 7                      11.850683                      12.183418
# 8                      11.018104                      10.962856
# 9                       9.999025                       9.852247
#
#    TMD_8_3_U_IO_DDA_30_E2_1_5160  TMD_8_4_T_IO_DDA_30_F2_1_5162  \
# 0                       9.789927                      10.089345
# 1                       8.928256                       9.288782
# 2                       8.846468                       8.716585
# 3                       9.477080                       9.111724
# 4                      10.769873                      10.358631
# 5                      10.498139                      10.744624
# 6                       9.227886                       9.276409
# 7                      11.924306                      11.929726
# 8                      10.969336                      11.063367
# 9                      10.009648                      10.053329
#
#    U_2932_1_U_IO_DDA_30min_G5_1_5212  U_2932_2_T_IO_DDA_30min_H5_1_5214  \
# 0                           8.539033                           8.578702
# 1                           8.952269                           8.917941
# 2                           9.122460                           8.997914
# 3                           9.778208                           9.661671
# 4                           9.580386                           9.702839
# 5                           9.895304                           9.940205
# 6                          10.026413                          10.204148
# 7                          11.985862                          12.132372
# 8                          11.530372                          11.322636
# 9                           9.884916                           9.548240
#
#    U_2932_3_U_IO_DDA_30min_A6_1_5216  U_2932_4_T_IO_DDA_30min_B6_1_5218
# 0                           9.021260                           8.038641
# 1                           8.669605                           8.812814
# 2                           8.967428                           9.267760
# 3                           9.502039                           9.491149
# 4                           9.713053                          10.030737
# 5                           9.919951                           9.433004
# 6                          10.203185                          10.140258
# 7                          12.057108                          12.090550
# 8                          11.240526                          11.490179
# 9                           9.502562                           9.762039
#
# [10 rows x 49 columns]
#
# Denormalize Reconstructed Data:
#    Unnamed: 0  Balm_3_1_U_IO_DDA_30min_G6_1_5228  \
# 0       ILVBL                           6.973921
# 1     NA;NBAS                           8.937573
# 2  GTPBP10;NA                           8.672674
# 3         PGP                           6.967437
# 4     NA;AHSG                          11.804774
# 5      NA;VTN                          11.657632
# 6        AGPS                           7.734646
# 7      DDX39A                          12.539039
# 8      PDLIM1                           6.951622
# 9   SNAP23;NA                          10.131897
#
#    Balm_3_2_T_IO_DDA_30min_H6_1_5230  Balm_3_3_U_IO_DDA_30min_A7_1_5232  \
# 0                           8.935561                           4.991365
# 1                           9.367173                           4.967873
# 2                           8.955487                           4.983242
# 3                           8.596817                           4.978980
# 4                          11.778822                          11.864427
# 5                          11.734868                          11.481394
# 6                           8.684063                           7.679667
# 7                          12.550123                          12.240957
# 8                           6.969415                           4.990158
# 9                          10.263223                          10.213836
#
#    Balm_3_4_T_IO_DDA_30min_B7_1_5234  DOHH_2_1_U_IO_DDA_30_C4_1_5188  \
# 0                           5.029608                        9.220390
# 1                           5.003864                        8.467625
# 2                           5.031672                        9.159973
# 3                           5.027447                        7.365014
# 4                          12.075907                       11.444936
# 5                          11.648854                       10.742336
# 6                           8.159461                        7.157424
# 7                          12.363546                       12.325987
# 8                           5.054302                       10.126271
# 9                          10.403475                       10.098273
#
#    DOHH_2_2_T_IO_DDA_30_D4_1_5190  DOHH_2_3_U_IO_DDA_30_E4_1_5192  \
# 0                        6.505782                        6.723722
# 1                        8.535367                        8.729995
# 2                        8.743835                        9.052879
# 3                        8.679754                        6.719929
# 4                       11.350030                       11.449346
# 5                       10.826813                       10.547628
# 6                        6.701936                        6.903436
# 7                       12.205522                       12.242067
# 8                       10.439571                       10.071499
# 9                        9.944390                        9.698307
#
#    DOHH_2_4_T_IO_DDA_30_F4_1_5194  HBL_1_2_T_IO_DDA_30_H1_1_5150  ...  \
# 0                        8.950183                       7.888173  ...
# 1                        7.372575                       8.608477  ...
# 2                        8.759308                       8.201907  ...
# 3                        8.616568                       8.696092  ...
# 4                       11.749893                      10.275086  ...
# 5                       10.799984                       9.818202  ...
# 6                        7.368143                      10.039460  ...
# 7                       12.172878                      11.393241  ...
# 8                       10.054748                       9.722385  ...
# 9                       10.057667                       9.318657  ...
#
#    SU_DHL_5_3_U_IO_DDA_30_A3_1_5168  SU_DHL_5_4_T_IO_DDA_30_B3_1_5170  \
# 0                          7.007106                          8.759982
# 1                          8.315028                          8.735943
# 2                          8.343125                          8.468654
# 3                          8.671355                          8.798077
# 4                         10.704165                         10.541333
# 5                         11.217870                         11.342517
# 6                          8.264080                          8.173716
# 7                         12.259045                         12.171843
# 8                          9.267193                          9.296059
# 9                          9.905685                          9.594718
#
#    TMD_8_1_U_IO_DDA_30_C2_1_5156  TMD_8_2_T_IO_DDA_30_D2_1_5158  \
# 0                       9.557964                       9.990720
# 1                       8.788090                       9.369052
# 2                       8.710834                       8.975048
# 3                       9.370757                       8.818201
# 4                      10.565428                      10.897665
# 5                      10.643757                      10.609650
# 6                       9.246865                       9.285541
# 7                      11.850683                      12.183418
# 8                      11.018104                      10.962856
# 9                       9.999025                       9.852247
#
#    TMD_8_3_U_IO_DDA_30_E2_1_5160  TMD_8_4_T_IO_DDA_30_F2_1_5162  \
# 0                       9.789927                      10.089345
# 1                       8.928256                       9.288782
# 2                       8.846468                       8.716585
# 3                       9.477080                       9.111724
# 4                      10.769873                      10.358631
# 5                      10.498139                      10.744624
# 6                       9.227886                       9.276409
# 7                      11.924306                      11.929726
# 8                      10.969336                      11.063367
# 9                      10.009648                      10.053329
#
#    U_2932_1_U_IO_DDA_30min_G5_1_5212  U_2932_2_T_IO_DDA_30min_H5_1_5214  \
# 0                           8.539033                           8.578702
# 1                           8.952269                           8.917941
# 2                           9.122460                           8.997914
# 3                           9.778208                           9.661671
# 4                           9.580386                           9.702839
# 5                           9.895304                           9.940205
# 6                          10.026413                          10.204148
# 7                          11.985862                          12.132372
# 8                          11.530372                          11.322636
# 9                           9.884916                           9.548240
#
#    U_2932_3_U_IO_DDA_30min_A6_1_5216  U_2932_4_T_IO_DDA_30min_B6_1_5218
# 0                           9.021260                           8.038641
# 1                           8.669605                           8.812814
# 2                           8.967428                           9.267760
# 3                           9.502039                           9.491149
# 4                           9.713053                          10.030737
# 5                           9.919951                           9.433004
# 6                          10.203185                          10.140258
# 7                          12.057108                          12.090550
# 8                          11.240526                          11.490179
# 9                           9.502562                           9.762039
#
# [10 rows x 49 columns]
# RMSE: 0.05696452212724645
